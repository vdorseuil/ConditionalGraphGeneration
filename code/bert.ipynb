# %%
import argparse
import sys


import numpy as np
from torch_geometric.data import Data

import torch.nn.functional as F
from torch_geometric.loader import DataLoader


from utils import preprocess_dataset



from torch.utils.data import Subset
np.random.seed(13)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Simulate command-line arguments
sys.argv = [
    'main.py',
    '--lr', '0.001',
    '--dropout', '0.1',
    '--batch-size', '256',
    '--epochs-autoencoder', '200',
    '--hidden-dim-encoder', '64',
    '--hidden-dim-decoder', '256',
    '--latent-dim', '32',
    '--n-max-nodes', '50',
    '--n-layers-encoder', '2',
    '--n-layers-decoder', '3',
    '--spectral-emb-dim', '10',
    '--epochs-denoise', '100',
    '--timesteps', '500',
    '--hidden-dim-denoise', '512',
    '--n-layers_denoise', '3',
    # '--train-autoencoder',
    '--train-denoiser',
    '--dim-condition', '128',
    '--n-condition', '7'
]

# Initialize the parser
parser = argparse.ArgumentParser(description="Your description here")

# Add arguments
parser.add_argument('--lr', type=float, default=1e-3, help="Learning rate for the optimizer, typically a small float value (default: 0.001)")
parser.add_argument('--dropout', type=float, default=0.0, help="Dropout rate (fraction of nodes to drop) to prevent overfitting (default: 0.0)")
parser.add_argument('--batch-size', type=int, default=256, help="Batch size for training, controlling the number of samples per gradient update (default: 256)")
parser.add_argument('--epochs-autoencoder', type=int, default=200, help="Number of training epochs for the autoencoder (default: 200)")
parser.add_argument('--hidden-dim-encoder', type=int, default=64, help="Hidden dimension size for encoder layers (default: 64)")
parser.add_argument('--hidden-dim-decoder', type=int, default=256, help="Hidden dimension size for decoder layers (default: 256)")
parser.add_argument('--latent-dim', type=int, default=32, help="Dimensionality of the latent space in the autoencoder (default: 32)")
parser.add_argument('--n-max-nodes', type=int, default=50, help="Possible maximum number of nodes in graphs (default: 50)")
parser.add_argument('--n-layers-encoder', type=int, default=2, help="Number of layers in the encoder network (default: 2)")
parser.add_argument('--n-layers-decoder', type=int, default=3, help="Number of layers in the decoder network (default: 3)")
parser.add_argument('--spectral-emb-dim', type=int, default=20, help="Dimensionality of spectral embeddings for representing graph structures (default: 10)")
parser.add_argument('--epochs-denoise', type=int, default=100, help="Number of training epochs for the denoising model (default: 100)")
parser.add_argument('--timesteps', type=int, default=500, help="Number of timesteps for the diffusion (default: 500)")
parser.add_argument('--hidden-dim-denoise', type=int, default=512, help="Hidden dimension size for denoising model layers (default: 512)")
parser.add_argument('--n-layers_denoise', type=int, default=3, help="Number of layers in the denoising model (default: 3)")
parser.add_argument('--train-autoencoder', action='store_true', default=False, help="Flag to enable/disable autoencoder (VGAE) training (default: enabled)")
parser.add_argument('--train-denoiser', action='store_true', default=False, help="Flag to enable/disable denoiser training (default: enabled)")
parser.add_argument('--dim-condition', type=int, default=128, help="Dimensionality of conditioning vectors for conditional generation (default: 128)")
parser.add_argument('--n-condition', type=int, default=7, help="Number of distinct condition properties used in conditional vector (default: 7)")

# Parse the arguments
args = parser.parse_args()

# Use the arguments as needed
print(args)
# Out:
# Namespace(lr=0.001, dropout=0.1, batch_size=256, epochs_autoencoder=200, hidden_dim_encoder=64, hidden_dim_decoder=256, latent_dim=32, n_max_nodes=50, n_layers_encoder=2, n_layers_decoder=3, spectral_emb_dim=10, epochs_denoise=100, timesteps=500, hidden_dim_denoise=512, n_layers_denoise=3, train_autoencoder=False, train_denoiser=True, dim_condition=128, n_condition=7)

# %%
trainset = preprocess_dataset("train", args.n_max_nodes, args.spectral_emb_dim)
validset = preprocess_dataset("valid", args.n_max_nodes, args.spectral_emb_dim)
testset = preprocess_dataset("test", args.n_max_nodes, args.spectral_emb_dim)
# Out:
# 100%|██████████| 8000/8000 [00:25<00:00, 311.63it/s]
# Dataset ./data/dataset_train.pt saved
# 100%|██████████| 1000/1000 [00:10<00:00, 98.24it/s]
# Dataset ./data/dataset_valid.pt saved
# graph_0,This graph comprises 50 nodes and 589 edges. The average degree is equal to 23.56 and there are 3702 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6226034308779012 and 18 respectively. The graph consists of 3 communities.
#
# graph_1,This graph comprises 20 nodes and 19 edges. The average degree is equal to 1.9 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 4 communities.
#
# graph_2,This graph comprises 28 nodes and 165 edges. The average degree is equal to 11.785714285714286 and there are 387 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.4742647058823529 and 8 respectively. The graph consists of 3 communities.
#
# graph_3,This graph comprises 47 nodes and 1050 edges. The average degree is equal to 44.680851063829785 and there are 14914 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9736257997127562 and 41 respectively. The graph consists of 1 communities.
#
# graph_4,In this graph, there are 25 nodes connected by 75 edges. On average, each node is connected to 6.0 other nodes. Within the graph, there are 22 triangles, forming closed loops of nodes. The global clustering coefficient is 0.176. Additionally, the graph has a maximum k-core of 6 and a number of communities equal to 3.
#
# graph_5,In this graph, there are 31 nodes connected by 121 edges. On average, each node is connected to 7.806451612903226 other nodes. Within the graph, there are 144 triangles, forming closed loops of nodes. The global clustering coefficient is 0.384. Additionally, the graph has a maximum k-core of 5 and a number of communities equal to 3.
#
# graph_6,This graph comprises 33 nodes and 198 edges. The average degree is equal to 12.0 and there are 241 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.3319559228650138 and 12 respectively. The graph consists of 5 communities.
#
# graph_7,In this graph, there are 15 nodes connected by 14 edges. On average, each node is connected to 1.8666666666666667 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 4.
#
# graph_8,In this graph, there are 16 nodes connected by 92 edges. On average, each node is connected to 11.5 other nodes. Within the graph, there are 251 triangles, forming closed loops of nodes. The global clustering coefficient is 0.7590725806451613. Additionally, the graph has a maximum k-core of 9 and a number of communities equal to 3.
#
# graph_9,In this graph, there are 20 nodes connected by 79 edges. On average, each node is connected to 7.9 other nodes. Within the graph, there are 126 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5170998632010944. Additionally, the graph has a maximum k-core of 7 and a number of communities equal to 3.
#
# graph_10,This graph comprises 20 nodes and 94 edges. The average degree is equal to 9.4 and there are 138 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5 and 6 respectively. The graph consists of 3 communities.
#
# graph_11,In this graph, there are 41 nodes connected by 481 edges. On average, each node is connected to 23.463414634146343 other nodes. Within the graph, there are 2134 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5831663326653307. Additionally, the graph has a maximum k-core of 18 and a number of communities equal to 3.
#
# graph_12,In this graph, there are 35 nodes connected by 178 edges. On average, each node is connected to 10.17142857142857 other nodes. Within the graph, there are 176 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2979683972911964. Additionally, the graph has a maximum k-core of 8 and a number of communities equal to 4.
#
# graph_13,In this graph, there are 30 nodes connected by 420 edges. On average, each node is connected to 28.0 other nodes. Within the graph, there are 3650 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9647577092511013. Additionally, the graph has a maximum k-core of 26 and a number of communities equal to 2.
#
# graph_14,In this graph, there are 49 nodes connected by 392 edges. On average, each node is connected to 16.0 other nodes. Within the graph, there are 608 triangles, forming closed loops of nodes. The global clustering coefficient is 0.31020408163265306. Additionally, the graph has a maximum k-core of 16 and a number of communities equal to 4.
#
# graph_15,This graph comprises 10 nodes and 20 edges. The average degree is equal to 4.0 and there are 8 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.34782608695652173 and 3 respectively. The graph consists of 2 communities.
#
# graph_16,This graph comprises 38 nodes and 190 edges. The average degree is equal to 10.0 and there are 162 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.2627027027027027 and 7 respectively. The graph consists of 5 communities.
#
# graph_17,In this graph, there are 19 nodes connected by 50 edges. On average, each node is connected to 5.2631578947368425 other nodes. Within the graph, there are 51 triangles, forming closed loops of nodes. The global clustering coefficient is 0.3355263157894737. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 2.
#
# graph_18,This graph comprises 16 nodes and 112 edges. The average degree is equal to 14 and there are 448 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9230769230769231 and 14 respectively. The graph consists of 2 communities.
#
# graph_19,This graph comprises 48 nodes and 677 edges. The average degree is equal to 28.208333333333332 and there are 7770 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9980304846720329 and 36 respectively. The graph consists of 2 communities.
#
# graph_20,This graph comprises 46 nodes and 1035 edges. The average degree is equal to 45.0 and there are 15180 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 1.0 and 45 respectively. The graph consists of 1 communities.
#
# graph_21,This graph comprises 46 nodes and 321 edges. The average degree is equal to 13.956521739130435 and there are 2300 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.993663594470046 and 24 respectively. The graph consists of 2 communities.
#
# graph_22,This graph comprises 39 nodes and 74 edges. The average degree is equal to 3.7948717948717947 and there are 36 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.07686832740213523 and 2 respectively. The graph consists of 1 communities.
#
# graph_23,In this graph, there are 12 nodes connected by 63 edges. On average, each node is connected to 10.5 other nodes. Within the graph, there are 190 triangles, forming closed loops of nodes. The global clustering coefficient is 0.95. Additionally, the graph has a maximum k-core of 10 and a number of communities equal to 1.
#
# graph_24,This graph comprises 49 nodes and 528 edges. The average degree is equal to 21.551020408163264 and there are 2418 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5511320468013979 and 15 respectively. The graph consists of 4 communities.
#
# graph_25,In this graph, there are 43 nodes connected by 817 edges. On average, each node is connected to 38.0 other nodes. Within the graph, there are 9067 triangles, forming closed loops of nodes. The global clustering coefficient is 0.8998312878361838. Additionally, the graph has a maximum k-core of 38 and a number of communities equal to 2.
#
# graph_26,In this graph, there are 21 nodes connected by 108 edges. On average, each node is connected to 10.285714285714286 other nodes. Within the graph, there are 202 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5906432748538012. Additionally, the graph has a maximum k-core of 8 and a number of communities equal to 3.
#
# graph_27,This graph comprises 29 nodes and 384 edges. The average degree is equal to 26.482758620689655 and there are 3186 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9651620720993638 and 25 respectively. The graph consists of 2 communities.
#
# graph_28,This graph comprises 22 nodes and 37 edges. The average degree is equal to 3.3636363636363638 and there are 16 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.13370473537604458 and 2 respectively. The graph consists of 2 communities.
#
# graph_29,This graph comprises 44 nodes and 264 edges. The average degree is equal to 12.0 and there are 225 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.23243801652892562 and 12 respectively. The graph consists of 5 communities.
#
# graph_30,In this graph, there are 45 nodes connected by 149 edges. On average, each node is connected to 6.622222222222222 other nodes. Within the graph, there are 560 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9750435287289612. Additionally, the graph has a maximum k-core of 15 and a number of communities equal to 4.
#
# graph_31,This graph comprises 48 nodes and 783 edges. The average degree is equal to 32.625 and there are 5738 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6898292858860303 and 27 respectively. The graph consists of 5 communities.
#
# graph_32,In this graph, there are 12 nodes connected by 16 edges. On average, each node is connected to 2.6666666666666665 other nodes. Within the graph, there are 5 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2112676056338028. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 2.
#
# graph_33,In this graph, there are 23 nodes connected by 100 edges. On average, each node is connected to 8.695652173913043 other nodes. Within the graph, there are 364 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9811320754716981. Additionally, the graph has a maximum k-core of 13 and a number of communities equal to 2.
#
# graph_34,This graph comprises 40 nodes and 702 edges. The average degree is equal to 35.1 and there are 7640 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9363127578740962 and 34 respectively. The graph consists of 2 communities.
#
# graph_35,In this graph, there are 36 nodes connected by 351 edges. On average, each node is connected to 19.5 other nodes. Within the graph, there are 1576 triangles, forming closed loops of nodes. The global clustering coefficient is 0.6490048043925875. Additionally, the graph has a maximum k-core of 14 and a number of communities equal to 4.
#
# graph_36,In this graph, there are 43 nodes connected by 48 edges. On average, each node is connected to 2.2325581395348837 other nodes. Within the graph, there are 10 triangles, forming closed loops of nodes. The global clustering coefficient is 0.4225352112676056. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 6.
#
# graph_37,In this graph, there are 21 nodes connected by 20 edges. On average, each node is connected to 1.9047619047619047 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 4.
#
# graph_38,In this graph, there are 14 nodes connected by 37 edges. On average, each node is connected to 5.285714285714286 other nodes. Within the graph, there are 35 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5198019801980198. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 3.
#
# graph_39,In this graph, there are 34 nodes connected by 33 edges. On average, each node is connected to 1.9411764705882353 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 6.
#
# graph_40,This graph comprises 28 nodes and 90 edges. The average degree is equal to 6.428571428571429 and there are 118 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.2875710804224208 and 4 respectively. The graph consists of 3 communities.
#
# graph_41,This graph comprises 30 nodes and 283 edges. The average degree is equal to 18.866666666666667 and there are 1110 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6476079346557759 and 15 respectively. The graph consists of 3 communities.
#
# graph_42,This graph comprises 43 nodes and 387 edges. The average degree is equal to 18.0 and there are 891 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.4062927496580027 and 18 respectively. The graph consists of 5 communities.
#
# graph_43,In this graph, there are 39 nodes connected by 312 edges. On average, each node is connected to 16.0 other nodes. Within the graph, there are 660 triangles, forming closed loops of nodes. The global clustering coefficient is 0.41164241164241167. Additionally, the graph has a maximum k-core of 12 and a number of communities equal to 5.
#
# graph_44,This graph comprises 19 nodes and 34 edges. The average degree is equal to 3.5789473684210527 and there are 15 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.28662420382165604 and 2 respectively. The graph consists of 3 communities.
#
# graph_45,This graph comprises 19 nodes and 18 edges. The average degree is equal to 1.894736842105263 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 5 communities.
#
# graph_46,This graph comprises 48 nodes and 1092 edges. The average degree is equal to 45.5 and there are 15883 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9758340330541276 and 43 respectively. The graph consists of 2 communities.
#
# graph_47,This graph comprises 29 nodes and 28 edges. The average degree is equal to 1.9310344827586208 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 6 communities.
#
# graph_48,In this graph, there are 50 nodes connected by 96 edges. On average, each node is connected to 3.84 other nodes. Within the graph, there are 38 triangles, forming closed loops of nodes. The global clustering coefficient is 0.22529644268774704. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 7.
#
# graph_49,In this graph, there are 40 nodes connected by 364 edges. On average, each node is connected to 18.2 other nodes. Within the graph, there are 2925 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9956881879042324. Additionally, the graph has a maximum k-core of 26 and a number of communities equal to 2.
#
# graph_50,This graph comprises 37 nodes and 189 edges. The average degree is equal to 10.216216216216216 and there are 969 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9881033310673012 and 18 respectively. The graph consists of 2 communities.
#
# graph_51,This graph comprises 12 nodes and 29 edges. The average degree is equal to 4.833333333333333 and there are 29 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5272727272727272 and 4 respectively. The graph consists of 3 communities.
#
# graph_52,This graph comprises 25 nodes and 202 edges. The average degree is equal to 16.16 and there are 699 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6701821668264621 and 13 respectively. The graph consists of 3 communities.
#
# graph_53,In this graph, there are 50 nodes connected by 643 edges. On average, each node is connected to 25.72 other nodes. Within the graph, there are 2825 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5242808536962573. Additionally, the graph has a maximum k-core of 20 and a number of communities equal to 4.
#
# graph_54,This graph comprises 33 nodes and 110 edges. The average degree is equal to 6.666666666666667 and there are 364 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9723953695458593 and 13 respectively. The graph consists of 3 communities.
#
# graph_55,In this graph, there are 28 nodes connected by 364 edges. On average, each node is connected to 26.0 other nodes. Within the graph, there are 2926 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9630279758639605. Additionally, the graph has a maximum k-core of 24 and a number of communities equal to 1.
#
# graph_56,This graph comprises 29 nodes and 193 edges. The average degree is equal to 13.310344827586206 and there are 604 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5781748564135291 and 9 respectively. The graph consists of 3 communities.
#
# graph_57,In this graph, there are 30 nodes connected by 120 edges. On average, each node is connected to 8.0 other nodes. Within the graph, there are 455 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9798994974874372. Additionally, the graph has a maximum k-core of 14 and a number of communities equal to 2.
#
# graph_58,This graph comprises 41 nodes and 176 edges. The average degree is equal to 8.585365853658537 and there are 816 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9843184559710495 and 17 respectively. The graph consists of 3 communities.
#
# graph_59,This graph comprises 43 nodes and 252 edges. The average degree is equal to 11.720930232558139 and there are 670 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.34441398217957503 and 7 respectively. The graph consists of 3 communities.
#
# graph_60,In this graph, there are 14 nodes connected by 28 edges. On average, each node is connected to 4.0 other nodes. Within the graph, there are 9 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2727272727272727. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 4.
#
# graph_61,In this graph, there are 47 nodes connected by 1026 edges. On average, each node is connected to 43.659574468085104 other nodes. Within the graph, there are 14193 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9642420399474614. Additionally, the graph has a maximum k-core of 40 and a number of communities equal to 2.
#
# graph_62,In this graph, there are 39 nodes connected by 291 edges. On average, each node is connected to 14.923076923076923 other nodes. Within the graph, there are 2024 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9939433622524144. Additionally, the graph has a maximum k-core of 23 and a number of communities equal to 2.
#
# graph_63,In this graph, there are 48 nodes connected by 167 edges. On average, each node is connected to 6.958333333333333 other nodes. Within the graph, there are 680 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9779482262703739. Additionally, the graph has a maximum k-core of 16 and a number of communities equal to 4.
#
# graph_64,This graph comprises 10 nodes and 40 edges. The average degree is equal to 8 and there are 80 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.8571428571428571 and 8 respectively. The graph consists of 2 communities.
#
# graph_65,In this graph, there are 36 nodes connected by 35 edges. On average, each node is connected to 1.9444444444444444 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 6.
#
# graph_66,This graph comprises 37 nodes and 186 edges. The average degree is equal to 10.054054054054054 and there are 233 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.34501480750246794 and 6 respectively. The graph consists of 4 communities.
#
# graph_67,This graph comprises 32 nodes and 122 edges. The average degree is equal to 7.625 and there are 72 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.24351747463359638 and 5 respectively. The graph consists of 4 communities.
#
# graph_68,This graph comprises 46 nodes and 45 edges. The average degree is equal to 1.9565217391304348 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 6 communities.
#
# graph_69,In this graph, there are 50 nodes connected by 50 edges. On average, each node is connected to 2.0 other nodes. Within the graph, there are 1 triangles, forming closed loops of nodes. The global clustering coefficient is 0.058823529411764705. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 8.
#
# graph_70,In this graph, there are 42 nodes connected by 146 edges. On average, each node is connected to 6.9523809523809526 other nodes. Within the graph, there are 560 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9767441860465116. Additionally, the graph has a maximum k-core of 15 and a number of communities equal to 3.
#
# graph_71,In this graph, there are 13 nodes connected by 78 edges. On average, each node is connected to 12.0 other nodes. Within the graph, there are 286 triangles, forming closed loops of nodes. The global clustering coefficient is 1.0. Additionally, the graph has a maximum k-core of 12 and a number of communities equal to 1.
#
# graph_72,This graph comprises 17 nodes and 102 edges. The average degree is equal to 12.0 and there are 283 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.7427821522309711 and 10 respectively. The graph consists of 2 communities.
#
# graph_73,In this graph, there are 28 nodes connected by 336 edges. On average, each node is connected to 24.0 other nodes. Within the graph, there are 2294 triangles, forming closed loops of nodes. The global clustering coefficient is 0.8874274661508704. Additionally, the graph has a maximum k-core of 21 and a number of communities equal to 2.
#
# graph_74,In this graph, there are 46 nodes connected by 1012 edges. On average, each node is connected to 44.0 other nodes. Within the graph, there are 14186 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9775807414894105. Additionally, the graph has a maximum k-core of 42 and a number of communities equal to 2.
#
# graph_75,In this graph, there are 29 nodes connected by 319 edges. On average, each node is connected to 22.0 other nodes. Within the graph, there are 1759 triangles, forming closed loops of nodes. The global clustering coefficient is 0.7825893519205102. Additionally, the graph has a maximum k-core of 18 and a number of communities equal to 2.
#
# graph_76,This graph comprises 29 nodes and 74 edges. The average degree is equal to 5.103448275862069 and there are 35 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.3322784810126582 and 4 respectively. The graph consists of 5 communities.
#
# graph_77,In this graph, there are 38 nodes connected by 699 edges. On average, each node is connected to 36.78947368421053 other nodes. Within the graph, there are 8296 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9945652173913043. Additionally, the graph has a maximum k-core of 35 and a number of communities equal to 1.
#
# graph_78,This graph comprises 36 nodes and 58 edges. The average degree is equal to 3.2222222222222223 and there are 3 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.05454545454545454 and 3 respectively. The graph consists of 4 communities.
#
# graph_79,In this graph, there are 44 nodes connected by 744 edges. On average, each node is connected to 33.81818181818182 other nodes. Within the graph, there are 6451 triangles, forming closed loops of nodes. The global clustering coefficient is 0.7872513525607127. Additionally, the graph has a maximum k-core of 28 and a number of communities equal to 3.
#
# graph_80,In this graph, there are 24 nodes connected by 63 edges. On average, each node is connected to 5.25 other nodes. Within the graph, there are 58 triangles, forming closed loops of nodes. The global clustering coefficient is 0.23169107856191745. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 2.
#
# graph_81,This graph comprises 45 nodes and 495 edges. The average degree is equal to 22.0 and there are 1677 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.48398268398268396 and 22 respectively. The graph consists of 4 communities.
#
# graph_82,This graph comprises 10 nodes and 16 edges. The average degree is equal to 3.2 and there are 7 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.29577464788732394 and 2 respectively. The graph consists of 2 communities.
#
# graph_83,This graph comprises 33 nodes and 53 edges. The average degree is equal to 3.212121212121212 and there are 56 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.8442211055276382 and 7 respectively. The graph consists of 5 communities.
#
# graph_84,In this graph, there are 47 nodes connected by 46 edges. On average, each node is connected to 1.9574468085106382 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 7.
#
# graph_85,This graph comprises 18 nodes and 143 edges. The average degree is equal to 15.88888888888889 and there are 666 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9345182413470533 and 14 respectively. The graph consists of 2 communities.
#
# graph_86,In this graph, there are 40 nodes connected by 396 edges. On average, each node is connected to 19.8 other nodes. Within the graph, there are 1791 triangles, forming closed loops of nodes. The global clustering coefficient is 0.6061597472924187. Additionally, the graph has a maximum k-core of 14 and a number of communities equal to 4.
#
# graph_87,In this graph, there are 50 nodes connected by 500 edges. On average, each node is connected to 20.0 other nodes. Within the graph, there are 1296 triangles, forming closed loops of nodes. The global clustering coefficient is 0.4022346368715084. Additionally, the graph has a maximum k-core of 15 and a number of communities equal to 5.
#
# graph_88,This graph comprises 27 nodes and 149 edges. The average degree is equal to 11.037037037037036 and there are 215 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.4174757281553398 and 8 respectively. The graph consists of 4 communities.
#
# graph_89,This graph comprises 23 nodes and 120 edges. The average degree is equal to 10.434782608695652 and there are 225 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5232558139534884 and 8 respectively. The graph consists of 3 communities.
#
# graph_90,This graph comprises 18 nodes and 119 edges. The average degree is equal to 13.222222222222221 and there are 428 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.8364820846905537 and 11 respectively. The graph consists of 3 communities.
#
# graph_91,This graph comprises 44 nodes and 84 edges. The average degree is equal to 3.8181818181818183 and there are 41 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.06814404432132964 and 2 respectively. The graph consists of 2 communities.
#
# graph_92,This graph comprises 38 nodes and 37 edges. The average degree is equal to 1.9473684210526316 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 7 communities.
#
# graph_93,This graph comprises 21 nodes and 23 edges. The average degree is equal to 2.1904761904761907 and there are 4 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.3870967741935484 and 3 respectively. The graph consists of 4 communities.
#
# graph_94,In this graph, there are 36 nodes connected by 396 edges. On average, each node is connected to 22.0 other nodes. Within the graph, there are 1751 triangles, forming closed loops of nodes. The global clustering coefficient is 0.6247621313035204. Additionally, the graph has a maximum k-core of 18 and a number of communities equal to 3.
#
# graph_95,This graph comprises 13 nodes and 12 edges. The average degree is equal to 1.8461538461538463 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 1 communities.
#
# graph_96,In this graph, there are 21 nodes connected by 105 edges. On average, each node is connected to 10.0 other nodes. Within the graph, there are 143 triangles, forming closed loops of nodes. The global clustering coefficient is 0.45396825396825397. Additionally, the graph has a maximum k-core of 10 and a number of communities equal to 3.
#
# graph_97,This graph comprises 12 nodes and 11 edges. The average degree is equal to 1.8333333333333333 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 4 communities.
#
# graph_98,In this graph, there are 37 nodes connected by 584 edges. On average, each node is connected to 31.56756756756757 other nodes. Within the graph, there are 5277 triangles, forming closed loops of nodes. The global clustering coefficient is 0.8820972864545606. Additionally, the graph has a maximum k-core of 27 and a number of communities equal to 2.
#
# graph_99,This graph comprises 44 nodes and 660 edges. The average degree is equal to 30.0 and there are 4459 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6936838830118233 and 25 respectively. The graph consists of 4 communities.
#
# graph_100,In this graph, there are 23 nodes connected by 60 edges. On average, each node is connected to 5.217391304347826 other nodes. Within the graph, there are 32 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2782608695652174. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 4.
#
# graph_101,In this graph, there are 23 nodes connected by 184 edges. On average, each node is connected to 16.0 other nodes. Within the graph, there are 661 triangles, forming closed loops of nodes. The global clustering coefficient is 0.7125404240028747. Additionally, the graph has a maximum k-core of 14 and a number of communities equal to 3.
#
# graph_102,This graph comprises 49 nodes and 784 edges. The average degree is equal to 32.0 and there are 5445 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6655123243023019 and 27 respectively. The graph consists of 4 communities.
#
# graph_103,This graph comprises 44 nodes and 300 edges. The average degree is equal to 13.636363636363637 and there are 1005 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.4972785749628897 and 11 respectively. The graph consists of 4 communities.
#
# graph_104,In this graph, there are 17 nodes connected by 16 edges. On average, each node is connected to 1.8823529411764706 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 4.
#
# graph_105,In this graph, there are 37 nodes connected by 629 edges. On average, each node is connected to 34.0 other nodes. Within the graph, there are 6512 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9411764705882353. Additionally, the graph has a maximum k-core of 34 and a number of communities equal to 2.
#
# graph_106,This graph comprises 25 nodes and 238 edges. The average degree is equal to 19.04 and there are 1143 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.791185971389017 and 16 respectively. The graph consists of 3 communities.
#
# graph_107,This graph comprises 39 nodes and 351 edges. The average degree is equal to 18 and there are 902 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.45349421820010055 and 18 respectively. The graph consists of 4 communities.
#
# graph_108,This graph comprises 26 nodes and 25 edges. The average degree is equal to 1.9230769230769231 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 5 communities.
#
# graph_109,In this graph, there are 24 nodes connected by 240 edges. On average, each node is connected to 20.0 other nodes. Within the graph, there are 1315 triangles, forming closed loops of nodes. The global clustering coefficient is 0.861918287087612. Additionally, the graph has a maximum k-core of 18 and a number of communities equal to 2.
#
# graph_110,In this graph, there are 15 nodes connected by 60 edges. On average, each node is connected to 8.0 other nodes. Within the graph, there are 70 triangles, forming closed loops of nodes. The global clustering coefficient is 0.4918032786885246. Additionally, the graph has a maximum k-core of 6 and a number of communities equal to 3.
#
# graph_111,This graph comprises 36 nodes and 216 edges. The average degree is equal to 12.0 and there are 283 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.34596577017114916 and 9 respectively. The graph consists of 5 communities.
#
# graph_112,This graph comprises 46 nodes and 792 edges. The average degree is equal to 34.43478260869565 and there are 6942 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.7797955592166848 and 28 respectively. The graph consists of 2 communities.
#
# graph_113,In this graph, there are 15 nodes connected by 101 edges. On average, each node is connected to 13.466666666666667 other nodes. Within the graph, there are 404 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9603803486529319. Additionally, the graph has a maximum k-core of 12 and a number of communities equal to 1.
#
# graph_114,This graph comprises 15 nodes and 99 edges. The average degree is equal to 13.2 and there are 387 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9524200164068909 and 12 respectively. The graph consists of 1 communities.
#
# graph_115,This graph comprises 40 nodes and 640 edges. The average degree is equal to 32.0 and there are 5365 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.8112399193548387 and 32 respectively. The graph consists of 3 communities.
#
# graph_116,In this graph, there are 26 nodes connected by 46 edges. On average, each node is connected to 3.5384615384615383 other nodes. Within the graph, there are 56 triangles, forming closed loops of nodes. The global clustering coefficient is 0.875. Additionally, the graph has a maximum k-core of 7 and a number of communities equal to 4.
#
# graph_117,This graph comprises 23 nodes and 116 edges. The average degree is equal to 10.08695652173913 and there are 206 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5167224080267558 and 7 respectively. The graph consists of 3 communities.
#
# graph_118,In this graph, there are 22 nodes connected by 44 edges. On average, each node is connected to 4.0 other nodes. Within the graph, there are 5 triangles, forming closed loops of nodes. The global clustering coefficient is 0.11363636363636363. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 5.
#
# graph_119,This graph comprises 43 nodes and 190 edges. The average degree is equal to 8.837209302325581 and there are 353 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.24929378531073446 and 5 respectively. The graph consists of 2 communities.
#
# graph_120,In this graph, there are 13 nodes connected by 26 edges. On average, each node is connected to 4.0 other nodes. Within the graph, there are 7 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2692307692307692. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 3.
#
# graph_121,In this graph, there are 44 nodes connected by 390 edges. On average, each node is connected to 17.727272727272727 other nodes. Within the graph, there are 920 triangles, forming closed loops of nodes. The global clustering coefficient is 0.4113263785394933. Additionally, the graph has a maximum k-core of 13 and a number of communities equal to 5.
#
# graph_122,In this graph, there are 49 nodes connected by 49 edges. On average, each node is connected to 2.0 other nodes. Within the graph, there are 1 triangles, forming closed loops of nodes. The global clustering coefficient is 0.06. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 7.
#
# graph_123,In this graph, there are 24 nodes connected by 275 edges. On average, each node is connected to 22.916666666666668 other nodes. Within the graph, there are 2002 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9963503649635036. Additionally, the graph has a maximum k-core of 22 and a number of communities equal to 1.
#
# graph_124,In this graph, there are 34 nodes connected by 169 edges. On average, each node is connected to 9.941176470588236 other nodes. Within the graph, there are 236 triangles, forming closed loops of nodes. The global clustering coefficient is 0.3751987281399046. Additionally, the graph has a maximum k-core of 7 and a number of communities equal to 5.
#
# graph_125,This graph comprises 48 nodes and 384 edges. The average degree is equal to 16.0 and there are 647 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.32976554536187563 and 12 respectively. The graph consists of 5 communities.
#
# graph_126,This graph comprises 16 nodes and 80 edges. The average degree is equal to 10 and there are 150 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.625 and 10 respectively. The graph consists of 2 communities.
#
# graph_127,In this graph, there are 14 nodes connected by 78 edges. On average, each node is connected to 11.142857142857142 other nodes. Within the graph, there are 258 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9280575539568345. Additionally, the graph has a maximum k-core of 10 and a number of communities equal to 2.
#
# graph_128,In this graph, there are 13 nodes connected by 22 edges. On average, each node is connected to 3.3846153846153846 other nodes. Within the graph, there are 8 triangles, forming closed loops of nodes. The global clustering coefficient is 0.3. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 3.
#
# graph_129,This graph comprises 36 nodes and 323 edges. The average degree is equal to 17.944444444444443 and there are 1406 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6239644970414201 and 13 respectively. The graph consists of 4 communities.
#
# graph_130,In this graph, there are 50 nodes connected by 141 edges. On average, each node is connected to 5.64 other nodes. Within the graph, there are 87 triangles, forming closed loops of nodes. The global clustering coefficient is 0.22955145118733508. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 6.
#
# graph_131,In this graph, there are 34 nodes connected by 170 edges. On average, each node is connected to 10 other nodes. Within the graph, there are 121 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2372549019607843. Additionally, the graph has a maximum k-core of 10 and a number of communities equal to 4.
#
# graph_132,In this graph, there are 12 nodes connected by 32 edges. On average, each node is connected to 5.333333333333333 other nodes. Within the graph, there are 34 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5257731958762887. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 2.
#
# graph_133,This graph comprises 13 nodes and 39 edges. The average degree is equal to 6.0 and there are 37 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5045454545454545 and 5 respectively. The graph consists of 3 communities.
#
# graph_134,This graph comprises 28 nodes and 37 edges. The average degree is equal to 2.642857142857143 and there are 10 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.07481296758104738 and 2 respectively. The graph consists of 2 communities.
#
# graph_135,This graph comprises 42 nodes and 389 edges. The average degree is equal to 18.523809523809526 and there are 1676 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5669824086603519 and 13 respectively. The graph consists of 4 communities.
#
# graph_136,This graph comprises 27 nodes and 42 edges. The average degree is equal to 3.111111111111111 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 2 respectively. The graph consists of 4 communities.
#
# graph_137,This graph comprises 33 nodes and 138 edges. The average degree is equal to 8.363636363636363 and there are 186 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.40028694404591103 and 7 respectively. The graph consists of 4 communities.
#
# graph_138,In this graph, there are 24 nodes connected by 180 edges. On average, each node is connected to 15.0 other nodes. Within the graph, there are 522 triangles, forming closed loops of nodes. The global clustering coefficient is 0.6214285714285714. Additionally, the graph has a maximum k-core of 15 and a number of communities equal to 3.
#
# graph_139,In this graph, there are 12 nodes connected by 16 edges. On average, each node is connected to 2.6666666666666665 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 3.
#
# graph_140,This graph comprises 30 nodes and 200 edges. The average degree is equal to 13.333333333333334 and there are 673 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5813417794414051 and 10 respectively. The graph consists of 3 communities.
#
# graph_141,In this graph, there are 35 nodes connected by 134 edges. On average, each node is connected to 7.6571428571428575 other nodes. Within the graph, there are 214 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2775616083009079. Additionally, the graph has a maximum k-core of 5 and a number of communities equal to 2.
#
# graph_142,In this graph, there are 19 nodes connected by 76 edges. On average, each node is connected to 8.0 other nodes. Within the graph, there are 70 triangles, forming closed loops of nodes. The global clustering coefficient is 0.39473684210526316. Additionally, the graph has a maximum k-core of 8 and a number of communities equal to 3.
#
# graph_143,In this graph, there are 40 nodes connected by 58 edges. On average, each node is connected to 2.9 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 7.
#
# graph_144,This graph comprises 39 nodes and 129 edges. The average degree is equal to 6.615384615384615 and there are 455 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9736091298145506 and 14 respectively. The graph consists of 3 communities.
#
# graph_145,In this graph, there are 50 nodes connected by 674 edges. On average, each node is connected to 26.96 other nodes. Within the graph, there are 3206 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5417065615319628. Additionally, the graph has a maximum k-core of 22 and a number of communities equal to 5.
#
# graph_146,This graph comprises 19 nodes and 88 edges. The average degree is equal to 9.263157894736842 and there are 140 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5622489959839357 and 7 respectively. The graph consists of 2 communities.
#
# graph_147,In this graph, there are 11 nodes connected by 46 edges. On average, each node is connected to 8.363636363636363 other nodes. Within the graph, there are 120 triangles, forming closed loops of nodes. The global clustering coefficient is 0.975609756097561. Additionally, the graph has a maximum k-core of 9 and a number of communities equal to 2.
#
# graph_148,This graph comprises 10 nodes and 9 edges. The average degree is equal to 1.8 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 3 communities.
#
# graph_149,This graph comprises 30 nodes and 44 edges. The average degree is equal to 2.933333333333333 and there are 35 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.7894736842105263 and 6 respectively. The graph consists of 5 communities.
#
# graph_150,In this graph, there are 44 nodes connected by 900 edges. On average, each node is connected to 40.90909090909091 other nodes. Within the graph, there are 11690 triangles, forming closed loops of nodes. The global clustering coefficient is 0.967421588369976. Additionally, the graph has a maximum k-core of 37 and a number of communities equal to 2.
#
# ...
#
# graph_951,In this graph, there are 36 nodes connected by 214 edges. On average, each node is connected to 11.88888888888889 other nodes. Within the graph, there are 272 triangles, forming closed loops of nodes. The global clustering coefficient is 0.334289225727161. Additionally, the graph has a maximum k-core of 8 and a number of communities equal to 5.
#
# graph_952,In this graph, there are 26 nodes connected by 195 edges. On average, each node is connected to 15.0 other nodes. Within the graph, there are 583 triangles, forming closed loops of nodes. The global clustering coefficient is 0.6164962989072964. Additionally, the graph has a maximum k-core of 11 and a number of communities equal to 4.
#
# graph_953,In this graph, there are 42 nodes connected by 336 edges. On average, each node is connected to 16.0 other nodes. Within the graph, there are 652 triangles, forming closed loops of nodes. The global clustering coefficient is 0.37586471944657956. Additionally, the graph has a maximum k-core of 12 and a number of communities equal to 4.
#
# graph_954,This graph comprises 42 nodes and 168 edges. The average degree is equal to 8.0 and there are 155 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.38461538461538464 and 6 respectively. The graph consists of 4 communities.
#
# graph_955,In this graph, there are 27 nodes connected by 82 edges. On average, each node is connected to 6.074074074074074 other nodes. Within the graph, there are 36 triangles, forming closed loops of nodes. The global clustering coefficient is 0.23326133909287258. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 4.
#
# graph_956,In this graph, there are 14 nodes connected by 41 edges. On average, each node is connected to 5.857142857142857 other nodes. Within the graph, there are 84 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9545454545454546. Additionally, the graph has a maximum k-core of 8 and a number of communities equal to 2.
#
# graph_957,This graph comprises 27 nodes and 224 edges. The average degree is equal to 16.59259259259259 and there are 752 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6335299073294018 and 13 respectively. The graph consists of 3 communities.
#
# graph_958,This graph comprises 34 nodes and 37 edges. The average degree is equal to 2.176470588235294 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 2 respectively. The graph consists of 7 communities.
#
# graph_959,This graph comprises 25 nodes and 102 edges. The average degree is equal to 8.16 and there are 364 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.979372197309417 and 13 respectively. The graph consists of 2 communities.
#
# graph_960,In this graph, there are 32 nodes connected by 67 edges. On average, each node is connected to 4.1875 other nodes. Within the graph, there are 120 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9230769230769231. Additionally, the graph has a maximum k-core of 9 and a number of communities equal to 4.
#
# graph_961,This graph comprises 37 nodes and 154 edges. The average degree is equal to 8.324324324324325 and there are 80 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.19966722129783693 and 6 respectively. The graph consists of 6 communities.
#
# graph_962,This graph comprises 39 nodes and 137 edges. The average degree is equal to 7.0256410256410255 and there are 188 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.21052631578947367 and 4 respectively. The graph consists of 2 communities.
#
# graph_963,This graph comprises 20 nodes and 82 edges. The average degree is equal to 8.2 and there are 111 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.49333333333333335 and 6 respectively. The graph consists of 4 communities.
#
# graph_964,This graph comprises 44 nodes and 196 edges. The average degree is equal to 8.909090909090908 and there are 969 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9857578840284842 and 18 respectively. The graph consists of 3 communities.
#
# graph_965,In this graph, there are 21 nodes connected by 208 edges. On average, each node is connected to 19.80952380952381 other nodes. Within the graph, there are 1292 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9902912621359223. Additionally, the graph has a maximum k-core of 19 and a number of communities equal to 1.
#
# graph_966,In this graph, there are 27 nodes connected by 92 edges. On average, each node is connected to 6.814814814814815 other nodes. Within the graph, there are 125 triangles, forming closed loops of nodes. The global clustering coefficient is 0.29411764705882354. Additionally, the graph has a maximum k-core of 4 and a number of communities equal to 2.
#
# graph_967,This graph comprises 28 nodes and 279 edges. The average degree is equal to 19.928571428571427 and there are 1307 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.7328971962616823 and 16 respectively. The graph consists of 3 communities.
#
# graph_968,This graph comprises 21 nodes and 189 edges. The average degree is equal to 18.0 and there are 974 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9032457496136013 and 15 respectively. The graph consists of 2 communities.
#
# graph_969,In this graph, there are 21 nodes connected by 210 edges. On average, each node is connected to 20 other nodes. Within the graph, there are 1330 triangles, forming closed loops of nodes. The global clustering coefficient is 1.0. Additionally, the graph has a maximum k-core of 20 and a number of communities equal to 1.
#
# graph_970,In this graph, there are 18 nodes connected by 32 edges. On average, each node is connected to 3.5555555555555554 other nodes. Within the graph, there are 12 triangles, forming closed loops of nodes. The global clustering coefficient is 0.2748091603053435. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 5.
#
# graph_971,This graph comprises 38 nodes and 361 edges. The average degree is equal to 19.0 and there are 1578 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6066119938493081 and 14 respectively. The graph consists of 3 communities.
#
# graph_972,In this graph, there are 37 nodes connected by 78 edges. On average, each node is connected to 4.216216216216216 other nodes. Within the graph, there are 54 triangles, forming closed loops of nodes. The global clustering coefficient is 0.14173228346456693. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 3.
#
# graph_973,This graph comprises 39 nodes and 202 edges. The average degree is equal to 10.35897435897436 and there are 273 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.3432523051131601 and 7 respectively. The graph consists of 4 communities.
#
# graph_974,In this graph, there are 29 nodes connected by 348 edges. On average, each node is connected to 24.0 other nodes. Within the graph, there are 2284 triangles, forming closed loops of nodes. The global clustering coefficient is 0.8530876494023905. Additionally, the graph has a maximum k-core of 22 and a number of communities equal to 2.
#
# graph_975,This graph comprises 50 nodes and 141 edges. The average degree is equal to 5.64 and there are 57 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.1819148936170213 and 3 respectively. The graph consists of 6 communities.
#
# graph_976,In this graph, there are 49 nodes connected by 258 edges. On average, each node is connected to 10.53061224489796 other nodes. Within the graph, there are 1540 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9899292907649454. Additionally, the graph has a maximum k-core of 21 and a number of communities equal to 3.
#
# graph_977,In this graph, there are 15 nodes connected by 105 edges. On average, each node is connected to 14.0 other nodes. Within the graph, there are 455 triangles, forming closed loops of nodes. The global clustering coefficient is 1.0. Additionally, the graph has a maximum k-core of 14 and a number of communities equal to 1.
#
# graph_978,In this graph, there are 45 nodes connected by 705 edges. On average, each node is connected to 31.333333333333332 other nodes. Within the graph, there are 5113 triangles, forming closed loops of nodes. The global clustering coefficient is 0.7105007179582195. Additionally, the graph has a maximum k-core of 26 and a number of communities equal to 4.
#
# graph_979,This graph comprises 30 nodes and 279 edges. The average degree is equal to 18.6 and there are 1126 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.6649606299212598 and 14 respectively. The graph consists of 4 communities.
#
# graph_980,This graph comprises 34 nodes and 33 edges. The average degree is equal to 1.9411764705882353 and there are 0 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0 and 1 respectively. The graph consists of 6 communities.
#
# graph_981,In this graph, there are 17 nodes connected by 65 edges. On average, each node is connected to 7.647058823529412 other nodes. Within the graph, there are 65 triangles, forming closed loops of nodes. The global clustering coefficient is 0.42857142857142855. Additionally, the graph has a maximum k-core of 6 and a number of communities equal to 3.
#
# graph_982,This graph comprises 24 nodes and 194 edges. The average degree is equal to 16.166666666666668 and there are 1140 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9936083672283557 and 19 respectively. The graph consists of 2 communities.
#
# graph_983,In this graph, there are 43 nodes connected by 84 edges. On average, each node is connected to 3.9069767441860463 other nodes. Within the graph, there are 42 triangles, forming closed loops of nodes. The global clustering coefficient is 0.1276595744680851. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 7.
#
# graph_984,This graph comprises 26 nodes and 156 edges. The average degree is equal to 12.0 and there are 377 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.5319849482596425 and 9 respectively. The graph consists of 3 communities.
#
# graph_985,In this graph, there are 41 nodes connected by 40 edges. On average, each node is connected to 1.951219512195122 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 7.
#
# graph_986,This graph comprises 33 nodes and 198 edges. The average degree is equal to 12.0 and there are 240 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.3305785123966942 and 12 respectively. The graph consists of 4 communities.
#
# graph_987,In this graph, there are 38 nodes connected by 522 edges. On average, each node is connected to 27.473684210526315 other nodes. Within the graph, there are 4160 triangles, forming closed loops of nodes. The global clustering coefficient is 0.8379775733566105. Additionally, the graph has a maximum k-core of 23 and a number of communities equal to 3.
#
# graph_988,In this graph, there are 47 nodes connected by 463 edges. On average, each node is connected to 19.70212765957447 other nodes. Within the graph, there are 1227 triangles, forming closed loops of nodes. The global clustering coefficient is 0.4160262206148282. Additionally, the graph has a maximum k-core of 16 and a number of communities equal to 5.
#
# graph_989,This graph comprises 37 nodes and 564 edges. The average degree is equal to 30.486486486486488 and there are 5984 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.9980541502196031 and 33 respectively. The graph consists of 2 communities.
#
# graph_990,In this graph, there are 32 nodes connected by 219 edges. On average, each node is connected to 13.6875 other nodes. Within the graph, there are 718 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5414781297134238. Additionally, the graph has a maximum k-core of 10 and a number of communities equal to 2.
#
# graph_991,This graph comprises 44 nodes and 792 edges. The average degree is equal to 36.0 and there are 7666 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.8296536796536796 and 36 respectively. The graph consists of 2 communities.
#
# graph_992,In this graph, there are 39 nodes connected by 38 edges. On average, each node is connected to 1.9487179487179487 other nodes. Within the graph, there are 0 triangles, forming closed loops of nodes. The global clustering coefficient is 0. Additionally, the graph has a maximum k-core of 1 and a number of communities equal to 7.
#
# graph_993,In this graph, there are 13 nodes connected by 46 edges. On average, each node is connected to 7.076923076923077 other nodes. Within the graph, there are 54 triangles, forming closed loops of nodes. The global clustering coefficient is 0.5586206896551724. Additionally, the graph has a maximum k-core of 5 and a number of communities equal to 3.
#
# graph_994,In this graph, there are 23 nodes connected by 125 edges. On average, each node is connected to 10.869565217391305 other nodes. Within the graph, there are 207 triangles, forming closed loops of nodes. The global clustering coefficient is 0.4791666666666667. Additionally, the graph has a maximum k-core of 8 and a number of communities equal to 2.
#
# graph_995,In this graph, there are 17 nodes connected by 17 edges. On average, each node is connected to 2 other nodes. Within the graph, there are 1 triangles, forming closed loops of nodes. The global clustering coefficient is 0.17647058823529413. Additionally, the graph has a maximum k-core of 2 and a number of communities equal to 4.
#
# graph_996,This graph comprises 41 nodes and 552 edges. The average degree is equal to 26.926829268292682 and there are 3254 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.672221457099573 and 22 respectively. The graph consists of 4 communities.
#
# graph_997,This graph comprises 42 nodes and 210 edges. The average degree is equal to 10 and there are 129 triangles in the graph. The global clustering coefficient and the graph's maximum k-core are 0.20476190476190476 and 10 respectively. The graph consists of 4 communities.
#
# graph_998,In this graph, there are 17 nodes connected by 33 edges. On average, each node is connected to 3.8823529411764706 other nodes. Within the graph, there are 11 triangles, forming closed loops of nodes. The global clustering coefficient is 0.27049180327868855. Additionally, the graph has a maximum k-core of 3 and a number of communities equal to 3.
#
# graph_999,In this graph, there are 31 nodes connected by 75 edges. On average, each node is connected to 4.838709677419355 other nodes. Within the graph, there are 165 triangles, forming closed loops of nodes. The global clustering coefficient is 0.9446564885496184. Additionally, the graph has a maximum k-core of 10 and a number of communities equal to 4.
#
# Dataset ./data/dataset_test.pt saved

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
# Out:
#
#           1.4668e-02, -9.8397e-02, -4.7049e-02, -8.8550e-03, -8.8991e-02,
#           3.5100e-02, -1.2960e-01, -4.9887e-02, -6.1205e-02, -5.9780e-02,
#           9.4632e-03,  4.9122e-02, -7.7503e-02,  8.0973e-02, -4.7926e-02,
#           2.3438e-03,  7.5703e-02, -2.4018e-02, -1.5255e-02,  4.8674e-02,
#          -3.8597e-02, -7.0483e-02, -1.2035e-02, -3.8879e-02, -7.7602e-02,
#          -1.0724e-02,  1.0419e-02, -2.1375e-02, -9.1739e-02, -1.1134e-02,
#          -2.9607e-02,  2.4646e-02,  4.6571e-03, -1.6345e-02, -3.9522e-02,
#           7.7337e-02, -2.8473e-02, -3.6994e-03,  8.2767e-02, -1.1041e-02,
#           3.1398e-02,  5.3509e-02,  5.7515e-02, -3.1762e-02, -1.5291e-08,
#          -7.9966e-02, -4.7680e-02, -8.5979e-02,  5.6962e-02, -4.0887e-02,
#           2.2383e-02, -4.6445e-03, -3.8013e-02, -3.1067e-02, -1.0728e-02,
#           1.9770e-02,  7.7700e-03, -6.0947e-03, -3.8638e-02,  2.8027e-02,
#           6.7814e-02, -2.3535e-02,  3.2175e-02,  8.0254e-03, -2.3911e-02,
#          -1.2199e-03,  3.1460e-02, -5.2492e-02, -8.0681e-03,  3.1477e-03,
#           5.1150e-02, -4.4410e-02,  6.3601e-02,  3.8508e-02,  3.3043e-02,
#          -4.1873e-03,  4.9559e-02, -5.6961e-02, -6.4971e-03, -2.4979e-02,
#          -1.6087e-02,  6.6229e-02, -2.0631e-02,  1.0805e-01,  1.6855e-02,
#           1.4381e-02, -1.3213e-02, -1.2939e-01,  6.9522e-02, -5.5577e-02,
#          -6.7541e-02, -5.4582e-03, -6.1359e-03,  3.9084e-02, -6.2878e-02,
#           3.7406e-02, -1.1657e-02,  1.2915e-02, -5.5250e-02,  5.1608e-02,
#          -4.3084e-03,  5.8025e-02,  1.8694e-02,  2.2781e-02,  3.2167e-02,
#           5.3798e-02,  7.0285e-02,  7.4931e-02, -8.4177e-02]])

# %%
trainloader= DataLoader(trainset, batch_size=32)
validloader = DataLoader(validset, batch_size=32)
testloader = DataLoader(testset, batch_size=32)

# %%
res = {}
for name, loader in {"train": trainloader, "valid":validloader, "test":validset}.items():
    li = []
    for data in loader:
        data = data.to("cuda")
        encoded_input = tokenizer(data.text, padding=True, truncation=True, return_tensors='pt')
        with torch.no_grad():
            model_output = model(**encoded_input)
        sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
        li.append(sentence_embeddings)
    res[name] = torch.concat(li)

# %%
res["train"][0].unsqueeze(0).shape
# Out:
# torch.Size([1, 384])

# %%
def add_embeddings_to_dataset(dataset, mat):
    for i, data in enumerate(dataset):
        data.sentence_embeddings = mat[i].unsqueeze(0)
    return dataset

new_trainset = add_embeddings_to_dataset(trainset, res["train"])
new_validset = add_embeddings_to_dataset(validset, res["valid"])
new_testset = add_embeddings_to_dataset(testset, res["test"])

# %%
torch.save(new_trainset, './data/dataset_train.pt')
torch.save(new_validset, './data/dataset_valid.pt')
torch.save(new_testset, './data/dataset_test.pt')
